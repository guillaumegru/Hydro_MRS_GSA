# %% [markdown]
# # Postprocess GSA of hydrogeophysical model (v5.5, With MRS undetectable water V2)
#
# Histogram and pdf of signal MRS distributions

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

# %%
#STEP2 : Retrieve simulation data
simfiles_dir = 'Res_sim/'
fn_st = 'GSA5_5_'
n = '1'

# first set of simulation results
Y_E1_1 = np.loadtxt(simfiles_dir+fn_st+n+'_E1.csv', delimiter = ',')
Y_E2_1 = np.loadtxt(simfiles_dir+fn_st+n+'_E2.csv', delimiter = ',')
Y_E3_1 = np.loadtxt(simfiles_dir+fn_st+n+'_E3.csv', delimiter = ',')
Y_E4_1 = np.loadtxt(simfiles_dir+fn_st+n+'_E4.csv', delimiter = ',')
Y_E5_1 = np.loadtxt(simfiles_dir+fn_st+n+'_E5.csv', delimiter = ',')

X1 = np.loadtxt(simfiles_dir+fn_st+n+'_X.csv', delimiter = ',')[:Y_E1_1.shape[0],:]


# second set of simulation results
n = '2'

Y_E1_2 = np.loadtxt(simfiles_dir+fn_st+n+'_E1.csv', delimiter = ',')
Y_E2_2 = np.loadtxt(simfiles_dir+fn_st+n+'_E2.csv', delimiter = ',')
Y_E3_2 = np.loadtxt(simfiles_dir+fn_st+n+'_E3.csv', delimiter = ',')
Y_E4_2 = np.loadtxt(simfiles_dir+fn_st+n+'_E4.csv', delimiter = ',')
Y_E5_2 = np.loadtxt(simfiles_dir+fn_st+n+'_E5.csv', delimiter = ',')

X2 = np.loadtxt(simfiles_dir+fn_st+n+'_X.csv', delimiter = ',')[:Y_E1_2.shape[0],:]

n = '3'

Y_E1_3 = np.loadtxt(simfiles_dir+fn_st+n+'_E1.csv', delimiter = ',')
Y_E2_3 = np.loadtxt(simfiles_dir+fn_st+n+'_E2.csv', delimiter = ',')
Y_E3_3 = np.loadtxt(simfiles_dir+fn_st+n+'_E3.csv', delimiter = ',')
Y_E4_3 = np.loadtxt(simfiles_dir+fn_st+n+'_E4.csv', delimiter = ',')
Y_E5_3 = np.loadtxt(simfiles_dir+fn_st+n+'_E5.csv', delimiter = ',')

X3 = np.loadtxt(simfiles_dir+fn_st+n+'_X.csv', delimiter = ',')[:Y_E1_3.shape[0],:]

n = '4'

Y_E1_4 = np.loadtxt(simfiles_dir+fn_st+n+'_E1.csv', delimiter = ',')
Y_E2_4 = np.loadtxt(simfiles_dir+fn_st+n+'_E2.csv', delimiter = ',')
Y_E3_4 = np.loadtxt(simfiles_dir+fn_st+n+'_E3.csv', delimiter = ',')
Y_E4_4 = np.loadtxt(simfiles_dir+fn_st+n+'_E4.csv', delimiter = ',')
Y_E5_4 = np.loadtxt(simfiles_dir+fn_st+n+'_E5.csv', delimiter = ',')

X4 = np.loadtxt(simfiles_dir+fn_st+n+'_X.csv', delimiter = ',')[:Y_E1_4.shape[0],:]

n = '5'

Y_E1_5 = np.loadtxt(simfiles_dir+fn_st+n+'_E1.csv', delimiter = ',')
Y_E2_5 = np.loadtxt(simfiles_dir+fn_st+n+'_E2.csv', delimiter = ',')
Y_E3_5 = np.loadtxt(simfiles_dir+fn_st+n+'_E3.csv', delimiter = ',')
Y_E4_5 = np.loadtxt(simfiles_dir+fn_st+n+'_E4.csv', delimiter = ',')
Y_E5_5 = np.loadtxt(simfiles_dir+fn_st+n+'_E5.csv', delimiter = ',')

X5 = np.loadtxt(simfiles_dir+fn_st+n+'_X.csv', delimiter = ',')[:Y_E1_5.shape[0],:]

n = '6'

Y_E1_6 = np.loadtxt(simfiles_dir+fn_st+n+'_E1.csv', delimiter = ',')
Y_E2_6 = np.loadtxt(simfiles_dir+fn_st+n+'_E2.csv', delimiter = ',')
Y_E3_6 = np.loadtxt(simfiles_dir+fn_st+n+'_E3.csv', delimiter = ',')
Y_E4_6 = np.loadtxt(simfiles_dir+fn_st+n+'_E4.csv', delimiter = ',')
Y_E5_6 = np.loadtxt(simfiles_dir+fn_st+n+'_E5.csv', delimiter = ',')

X6 = np.loadtxt(simfiles_dir+fn_st+n+'_X.csv', delimiter = ',')[:Y_E1_6.shape[0],:]

n = '7'

Y_E1_7 = np.loadtxt(simfiles_dir+fn_st+n+'_E1.csv', delimiter = ',')
Y_E2_7 = np.loadtxt(simfiles_dir+fn_st+n+'_E2.csv', delimiter = ',')
Y_E3_7 = np.loadtxt(simfiles_dir+fn_st+n+'_E3.csv', delimiter = ',')
Y_E4_7 = np.loadtxt(simfiles_dir+fn_st+n+'_E4.csv', delimiter = ',')
Y_E5_7 = np.loadtxt(simfiles_dir+fn_st+n+'_E5.csv', delimiter = ',')

X7 = np.loadtxt(simfiles_dir+fn_st+n+'_X.csv', delimiter = ',')[:Y_E1_7.shape[0],:]

n = '8'

Y_E1_8 = np.loadtxt(simfiles_dir+fn_st+n+'_E1.csv', delimiter = ',')
Y_E2_8 = np.loadtxt(simfiles_dir+fn_st+n+'_E2.csv', delimiter = ',')
Y_E3_8 = np.loadtxt(simfiles_dir+fn_st+n+'_E3.csv', delimiter = ',')
Y_E4_8 = np.loadtxt(simfiles_dir+fn_st+n+'_E4.csv', delimiter = ',')
Y_E5_8 = np.loadtxt(simfiles_dir+fn_st+n+'_E5.csv', delimiter = ',')

X8 = np.loadtxt(simfiles_dir+fn_st+n+'_X.csv', delimiter = ',')[:Y_E1_8.shape[0],:]


X = np.concatenate((X1,X2,X3,X4,X5,X6,X7,X8))
Y_E1 = np.concatenate((Y_E1_1,Y_E1_2,Y_E1_3,Y_E1_4,Y_E1_5, Y_E1_6, Y_E1_7, Y_E1_8))
Y_E2 = np.concatenate((Y_E2_1,Y_E2_2,Y_E2_3,Y_E2_4,Y_E2_5, Y_E2_6, Y_E2_7, Y_E2_8))
Y_E3 = np.concatenate((Y_E3_1,Y_E3_2,Y_E3_3,Y_E3_4,Y_E3_5, Y_E3_6, Y_E3_7, Y_E3_8))
Y_E4 = np.concatenate((Y_E4_1,Y_E4_2,Y_E4_3,Y_E4_4,Y_E4_5, Y_E4_6, Y_E4_7, Y_E4_8))
Y_E5 = np.concatenate((Y_E5_1,Y_E5_2,Y_E5_3,Y_E5_4,Y_E5_5, Y_E5_6, Y_E5_7, Y_E5_8))

# %%
Nsim_or = Y_E1.shape[0]

# %%
nanidx = np.argwhere(np.isnan(Y_E1[:,0]))

Y_E1 = np.delete(Y_E1, nanidx, 0)
Y_E2 = np.delete(Y_E2, nanidx, 0)
Y_E3 = np.delete(Y_E3, nanidx, 0)
Y_E4 = np.delete(Y_E4, nanidx, 0)
Y_E5 = np.delete(Y_E5, nanidx, 0)
X = np.delete(X, nanidx, 0)

# %%
Y_E1.shape
# Out:
# (9896, 66)

# %%
Nsim_success = Y_E1.shape[0] # Number of simulations after deleting NaN (non-convergent simulations)

# %%
print(str(nanidx.shape[0])+'/'+str(Nsim_or)+' simulations did not converge ('+str((nanidx.shape[0]/Nsim_or)*100)[:4]+' %).')
# Out:
# 104/10000 simulations did not converge (1.04 %).

# %%
t_toprint = [0, 5, 10, 30, 50] # simulation times to plot hist and pdf 
x_max = 360
y_max = 640

# %% [markdown]
# # q1

# %%
for t in t_toprint:
    plt.figure()
    plt.title('t = '+str(t)+' d')
    plt.hist(Y_E1[:,t], bins = 50)
    plt.xlabel(r'$E_0(q_1)$', fontsize=13)
    plt.xlim((0,x_max))
    #plt.ylim((0,y_max))
    plt.grid()
    plt.savefig('Figures/sig_hist_pdf/hist_E1_t'+str(t)+'.png')

# %%
plt.figure()
plt.title('Signal histograms')

for t in t_toprint:
    plt.hist(Y_E1[:,t], bins = 50, label ='t = '+str(t)+' d', alpha = 0.9)
plt.xlabel(r'$E_0(q_1)$', fontsize=13)
plt.xlim((0,x_max))
plt.ylim((0,y_max))
plt.legend()
plt.grid()
plt.savefig('Figures/sig_hist_pdf/hist_E1_all_t.png')

# %% [markdown]
# # q2

# %%
for t in t_toprint:
    plt.figure()
    plt.title('t = '+str(t)+' d')
    plt.hist(Y_E2[:,t], bins = 50)
    plt.xlabel(r'$E_0(q_2)$', fontsize=13)
    plt.xlim((0,x_max))
    plt.ylim((0,y_max))
    plt.grid()
    plt.savefig('Figures/sig_hist_pdf/hist_E2_t'+str(t)+'.png')

# %%
plt.figure()
plt.title('Signal histograms')

for t in t_toprint:
    plt.hist(Y_E2[:,t], bins = 50, label ='t = '+str(t)+' d', alpha = 0.9)
plt.xlim((0,x_max))
plt.ylim((0,y_max))
plt.xlabel(r'$E_0(q_2)$')
plt.legend()
plt.grid()
plt.savefig('Figures/sig_hist_pdf/hist_E2_all_t.png')

# %% [markdown]
# # q3

# %%
for t in t_toprint:
    plt.figure()
    plt.title('t = '+str(t)+' d')
    plt.hist(Y_E3[:,t], bins = 50)
    plt.xlabel(r'$E_0(q_3)$', fontsize=13)
    plt.xlim((0,x_max))
    plt.ylim((0,y_max))
    plt.grid()
    plt.savefig('Figures/sig_hist_pdf/hist_E3_t'+str(t)+'.png')

# %%
plt.figure()
plt.title('Signal histograms')

for t in t_toprint:
    plt.hist(Y_E3[:,t], bins = 50, label ='t = '+str(t)+' d', alpha = 0.9)
plt.xlabel(r'$E_0(q_3)$', fontsize=13)
plt.xlim((0,x_max))
plt.ylim((0,y_max))
plt.legend()
plt.grid()
plt.savefig('Figures/sig_hist_pdf/hist_E3_all_t.png')

# %% [markdown]
# # q4

# %%
for t in t_toprint:
    plt.figure()
    plt.title('t = '+str(t)+' d')
    plt.hist(Y_E4[:,t], bins = 50)
    plt.xlabel(r'$E_0(q_4)$', fontsize=13)
    plt.xlim((0,x_max))
    plt.ylim((0,y_max))
    plt.grid()
    plt.savefig('Figures/sig_hist_pdf/hist_E4_t'+str(t)+'.png')

# %%
plt.figure()
plt.title('Signal histograms')

for t in t_toprint:
    plt.hist(Y_E4[:,t], bins = 50, label ='t = '+str(t)+' d', alpha = 0.9)
plt.xlabel(r'$E_0(q_4)$', fontsize=13)
plt.xlim((0,x_max))
plt.ylim((0,y_max))
plt.legend()
plt.grid()
plt.savefig('Figures/sig_hist_pdf/hist_E4_all_t.png')

# %% [markdown]
# # q5

# %%
for t in t_toprint:
    plt.figure()
    plt.title('t = '+str(t)+' d')
    plt.hist(Y_E5[:,t], bins = 50)
    plt.xlabel(r'$E_0(q_5)$', fontsize=13)
    plt.xlim((0,x_max))
    plt.ylim((0,y_max))
    plt.grid()
    plt.savefig('Figures/sig_hist_pdf/hist_E5_t'+str(t)+'.png')

# %%
plt.figure()
plt.title('Signal histograms')

for t in t_toprint:
    plt.hist(Y_E5[:,t], bins = 50, label ='t = '+str(t)+' d', alpha = 0.9)
plt.xlabel(r'$E_0(q_5)$', fontsize=13)
plt.xlim((0,x_max))
plt.ylim((0,y_max))
plt.legend()
plt.grid()
plt.savefig('Figures/sig_hist_pdf/hist_E5_all_t.png')

# %% [markdown]
# # Estimate signal pdf

# %%
linestyles = ['dashed', 'solid', 'dotted', 'dashdot', (0,(5,1))]

batlow10 = [(1,25,89), (16,  63,  96), (28,  90,  98), (60, 109,  86), (104, 123,  62), (157, 137,  43), (210, 147,  67), (248, 161, 123), (253, 183, 188), (250, 204, 250)]
batlow10_2 = []

for t in batlow10:
    r = t[0]/255
    g = t[1]/255
    b = t[2]/255
    batlow10_2.append((r,g,b))

# %%
y_max_pdf = 0.023
fs = 15

# %% [markdown]
# ## q1

# %%
pdf_E1_kde = []
min_val = 1e3
max_val = 0

for t in t_toprint:
    min_val = min(min_val, np.min(Y_E1[:,t]))
    max_val = max(max_val, np.max(Y_E1[:,t]))
    pdf_E1_kde.append(gaussian_kde(Y_E1[:,t]))

# %%
nsamples = 1e4
xx = np.arange(0, x_max, x_max/nsamples)

# %%
pdf_E1_eval = []

for i in range(len(t_toprint)):
    pdf_E1_eval.append(pdf_E1_kde[i].evaluate(xx))

# %%
plt.figure()
plt.title('q1 (60 A.ms)', fontsize= fs)
for k, t in enumerate(t_toprint):
    plt.plot(xx,pdf_E1_eval[k], label = 't = '+str(t)+' d', color = batlow10_2[2*k], linestyle = linestyles[k])
plt.xlabel(r'$E_0(q1) [nV]$', fontsize= fs)
plt.ylabel('Probability density', fontsize = fs)
plt.xlim((0,x_max))
plt.ylim((0,y_max_pdf))
plt.xticks(fontsize= fs)
plt.yticks(fontsize= fs)
plt.grid()
plt.legend(fontsize= fs)
plt.savefig('Figures/sig_hist_pdf/pdf_plot_E1.jpg', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## q2

# %%
pdf_E2_kde = []
for t in t_toprint:
    pdf_E2_kde.append(gaussian_kde(Y_E2[:,t]))

# %%
pdf_E2_eval = []

for i in range(len(t_toprint)):
    pdf_E2_eval.append(pdf_E2_kde[i].evaluate(xx))

# %%
plt.figure()
plt.title('q2 (145 A.ms)', fontsize = fs)
for k, t in enumerate(t_toprint):
    plt.plot(xx,pdf_E2_eval[k], label = 't = '+str(t)+' d', color = batlow10_2[2*k], linestyle = linestyles[k])
plt.xlabel(r'$E_0(q2) [nV]$', fontsize = fs)
plt.ylabel('Probability density', fontsize = fs)
plt.xlim((0,x_max))
plt.ylim((0,y_max_pdf))
plt.xticks(fontsize= fs)
plt.yticks(fontsize= fs)
plt.grid()
plt.legend(fontsize = fs)
plt.savefig('Figures/sig_hist_pdf/pdf_plot_E2.jpg', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## q3

# %%
pdf_E3_kde = []
min_val = 1e3
max_val = 0

for t in t_toprint:
    pdf_E3_kde.append(gaussian_kde(Y_E3[:,t]))

# %%
pdf_E3_eval = []

for i in range(len(t_toprint)):
    pdf_E3_eval.append(pdf_E3_kde[i].evaluate(xx))

# %%
plt.figure()
plt.title('q3 (362 A.ms)', fontsize=fs)
for k, t in enumerate(t_toprint):
    plt.plot(xx,pdf_E3_eval[k], label = 't = '+str(t)+' d', color = batlow10_2[2*k], linestyle = linestyles[k])
plt.xlabel(r'$E_0(q3) [nV]$', fontsize=fs)
plt.ylabel('Probability density', fontsize = fs)
plt.xlim((0,x_max))
plt.ylim((0,y_max_pdf))
plt.xticks(fontsize= fs)
plt.yticks(fontsize= fs)
plt.grid()
plt.legend(fontsize=fs)
plt.savefig('Figures/sig_hist_pdf/pdf_plot_E3.jpg', dpi = 300, bbox_inches='tight')

# %% [markdown]
# ## q4

# %%
pdf_E4_kde = []

for t in t_toprint:
    pdf_E4_kde.append(gaussian_kde(Y_E4[:,t]))

# %%
nsamples = 1e4
xx = np.arange(min_val, max_val, (max_val-min_val)/nsamples)

# %%
pdf_E4_eval = []

for i in range(len(t_toprint)):
    pdf_E4_eval.append(pdf_E4_kde[i].evaluate(xx))

# %%
plt.figure()
plt.title('q4 (904 A.ms)', fontsize=fs)
for k, t in enumerate(t_toprint):
    plt.plot(xx,pdf_E4_eval[k], label = 't = '+str(t)+' d', color = batlow10_2[2*k], linestyle = linestyles[k])
plt.xlabel(r'$E_0(q4) [nV]$', fontsize=fs)
plt.ylabel('Probability density', fontsize = fs)
plt.xlim((0,x_max))
plt.ylim((0,y_max_pdf))
plt.xticks(fontsize= fs)
plt.yticks(fontsize= fs)
plt.grid()
plt.legend(fontsize=fs)
plt.savefig('Figures/sig_hist_pdf/pdf_plot_E4.jpg', dpi=300, bbox_inches='tight')

# %% [markdown]
# ## q5

# %%
pdf_E5_kde = []

for t in t_toprint:
    pdf_E5_kde.append(gaussian_kde(Y_E5[:,t]))

# %%
pdf_E5_eval = []

for i in range(len(t_toprint)):
    pdf_E5_eval.append(pdf_E5_kde[i].evaluate(xx))

# %%
plt.figure()
plt.title('q5 (2260 A.ms)', fontsize=fs)
for k, t in enumerate(t_toprint):
    plt.plot(xx,pdf_E5_eval[k], label = 't = '+str(t)+' d', color = batlow10_2[2*k], linestyle = linestyles[k])
plt.xlabel(r'$E_0(q5) [nV]$', fontsize=fs)
plt.ylabel('Probability density', fontsize = fs)
plt.xlim((0,x_max))
plt.ylim((0,y_max_pdf))
plt.xticks(fontsize= fs)
plt.yticks(fontsize= fs)
plt.grid()
plt.legend(fontsize=fs)
plt.savefig('Figures/sig_hist_pdf/pdf_plot_E5.jpg', dpi=300, bbox_inches='tight')
